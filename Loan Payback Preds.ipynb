# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
train_df = pd.read_csv('train_lo.csv')

# %%
test_df = pd.read_csv('test_lo.csv')

# %%
#shape of train and test dataframe
print(f'Train_df Shape:', train_df.shape)
print(f'Test_df Shape:', test_df.shape)
# Out:
# Train_df Shape: (593994, 13)
# Test_df Shape: (254569, 12)

# %%
train_df['dataset'] = 'train'
test_df['dataset'] = 'test'

# %%
#combine the train and test df
df = pd.concat([train_df,test_df], ignore_index=True)

# %%
#first few row the dataframe
df.head()
# Out:
#    id  annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0   0       29367.99                 0.084           736      2528.42
# 1   1       22108.02                 0.166           636      4593.10
# 2   2       49566.20                 0.097           694     17005.15
# 3   3       46858.25                 0.065           533      4682.48
# 4   4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender marital_status education_level employment_status  \
# 0          13.67  Female         Single     High School     Self-employed
# 1          12.92    Male        Married        Master's          Employed
# 2           9.76    Male         Single     High School          Employed
# 3          16.10  Female         Single     High School          Employed
# 4          10.21    Male        Married     High School          Employed
#
#          loan_purpose grade_subgrade  loan_paid_back dataset
# ...

# %%
#annual_income_bracket,credit_score_bracket,debt_payment,

# %%
df.iloc[:len(train_df)]#.isnull().sum()
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 0            0       29367.99                 0.084           736
# 1            1       22108.02                 0.166           636
# 2            2       49566.20                 0.097           694
# 3            3       46858.25                 0.065           533
# 4            4       25496.70                 0.053           665
# ...        ...            ...                   ...           ...
# 593989  593989       23004.26                 0.152           703
# 593990  593990       35289.43                 0.105           559
# 593991  593991       47112.64                 0.072           675
# 593992  593992       76748.44                 0.067           740
# 593993  593993       48959.52                 0.096           752
#
#         loan_amount  interest_rate  gender marital_status education_level  \
# 0           2528.42          13.67  Female         Single     High School
# ...

# %%
df.iloc[len(train_df):]#.isnull().sum()
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 593994  593994       28781.05                 0.049           626
# 593995  593995       46626.39                 0.093           732
# 593996  593996       54954.89                 0.367           611
# 593997  593997       25644.63                 0.110           671
# 593998  593998       25169.64                 0.081           688
# ...        ...            ...                   ...           ...
# 848558  848558       92835.97                 0.068           744
# 848559  848559       48846.47                 0.091           634
# 848560  848560       20668.52                 0.096           718
# 848561  848561       34105.09                 0.094           739
# 848562  848562       45627.53                 0.118           624
#
#         loan_amount  interest_rate  gender marital_status education_level  \
# 593994     11461.42          14.73  Female         Single     High School
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848563 entries, 0 to 848562
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    848563 non-null  int64
#  1   annual_income         848563 non-null  float64
#  2   debt_to_income_ratio  848563 non-null  float64
#  3   credit_score          848563 non-null  int64
#  4   loan_amount           848563 non-null  float64
#  5   interest_rate         848563 non-null  float64
#  6   gender                848563 non-null  object
#  7   marital_status        848563 non-null  object
#  8   education_level       848563 non-null  object
#  9   employment_status     848563 non-null  object
#  10  loan_purpose          848563 non-null  object
#  11  grade_subgrade        848563 non-null  object
#  12  loan_paid_back        593994 non-null  float64
#  13  dataset               848563 non-null  object
# ...

# %%
#names of colums in the df
df.columns.tolist()
# Out:
# ['id',
#  'annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'gender',
#  'marital_status',
#  'education_level',
#  'employment_status',
#  'loan_purpose',
#  'grade_subgrade',
#  'loan_paid_back',
#  'dataset']

# %%
#checking for null values
df.isnull().sum()
# Out:
# id                           0
# annual_income                0
# debt_to_income_ratio         0
# credit_score                 0
# loan_amount                  0
# interest_rate                0
# gender                       0
# marital_status               0
# education_level              0
# employment_status            0
# loan_purpose                 0
# grade_subgrade               0
# loan_paid_back          254569
# dataset                      0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
#descriptive statistics
df.describe()
# Out:
#                   id  annual_income  debt_to_income_ratio   credit_score  \
# count  848563.000000  848563.000000         848563.000000  848563.000000
# mean   424281.000000   48218.466144              0.120662     680.952514
# std    244959.182573   26714.243232              0.068576      55.484775
# min         0.000000    6002.430000              0.011000     395.000000
# 25%    212140.500000   27939.785000              0.072000     646.000000
# 50%    424281.000000   46552.600000              0.096000     682.000000
# 75%    636421.500000   61003.900000              0.156000     719.000000
# max    848562.000000  393381.740000              0.627000     849.000000
#
#          loan_amount  interest_rate  loan_paid_back
# count  848563.000000  848563.000000   593994.000000
# mean    15019.234385      12.355139        0.798820
# std      6925.217352       2.011555        0.400883
# min       500.050000       3.200000        0.000000
# ...

# %%
#distribution of gender
sns.histplot(df['gender'], color='#8B5CF6');
# Out:
# C:\Users\HELLO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
target_col = df.columns.tolist()[-2]

# %%
df[target_col].value_counts()
# Out:
# loan_paid_back
# 1.0    474494
# 0.0    119500
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(16, 6), facecolor='#0d1117')
gs = fig.add_gridspec(1, 2, hspace=0.3, wspace=0.3)

# Count plot with modern styling
ax1 = fig.add_subplot(gs[0, 0])
target_counts = df[target_col].value_counts().sort_index()
x_pos = np.arange(len(target_counts))
bars = ax1.bar(x_pos, target_counts.values, width=0.6, 
               color=['#7b2cbf', '#c77dff'], edgecolor='none', alpha=0.9)

# Add gradient effect
for i, bar in enumerate(bars):
    bar.set_linewidth(0)
    bar.set_zorder(2)

ax1.set_xticks(x_pos)
ax1.set_xticklabels(['Not Paid Back', 'Paid Back'], fontsize=11, color='#c9d1d9')
ax1.set_ylabel('Count', fontsize=12, color='#c9d1d9', labelpad=10)
ax1.set_title('Loan Repayment Distribution', fontsize=15, color='#e0aaff', 
              pad=15, weight='600')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_color('#30363d')
ax1.spines['bottom'].set_color('#30363d')
ax1.grid(axis='y', alpha=0.3, linestyle='--', linewidth=0.5)


# Modern value labels
total = len(train_df)
for i, (bar, count) in enumerate(zip(bars, target_counts.values)):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + total*0.01,
             f'{count:,}', ha='center', va='bottom', 
             color='#e0aaff', fontsize=10, weight='600')
    ax1.text(bar.get_x() + bar.get_width()/2., height/2,
             f'{count/total*100:.1f}%', ha='center', va='center', 
             color='#ffffff', fontsize=13, weight='700')

# Modern donut chart
ax2 = fig.add_subplot(gs[0, 1])
colors = ['#7b2cbf', '#c77dff']
wedges, texts, autotexts = ax2.pie(target_counts.values, labels=None,
                                     autopct='%1.1f%%', startangle=90,
                                     colors=colors, wedgeprops=dict(width=0.5, edgecolor='#161b22', linewidth=2))

for autotext in autotexts:
    autotext.set_color('#ffffff')
    autotext.set_fontsize(13)
    autotext.set_weight('700')

ax2.set_title('Repayment Proportion', fontsize=15, color='#e0aaff', pad=15, weight='600')
ax2.legend(['Not Paid Back', 'Paid Back'], loc='upper left', 
           frameon=True, facecolor='#161b22', edgecolor='#30363d',
           fontsize=10, labelcolor='#c9d1d9')

plt.tight_layout()
plt.show()

print(f"\nClass Distribution:")
print(f"Paid Back: {target_counts[1]:,} ({target_counts[1]/total*100:.2f}%)")
print(f"Not Paid Back: {target_counts[0]:,} ({target_counts[0]/total*100:.2f}%)");
# Out:
# C:\Users\HELLO\AppData\Local\Temp\ipykernel_18844\2031162091.py:56: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Class Distribution:
# Paid Back: 474,494 (79.88%)
# Not Paid Back: 119,500 (20.12%)

# %%
df[['annual_income','employment_status']].groupby('employment_status')['annual_income'].mean().round(2)
# Out:
# employment_status
# Employed         48236.71
# Retired          48709.32
# Self-employed    48179.53
# Student          47852.60
# Unemployed       48059.74
# Name: annual_income, dtype: float64

# %%
sns.histplot(df['loan_amount'],color='#8B5CF6');
plt.title('Distribution Of Loan Amount')
# Out:
# C:\Users\HELLO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution Of Loan Amount')

# %%
sns.boxplot(df['credit_score']);

# %%
sns.boxplot(df['annual_income']);

# %% [markdown]
# ### Feature Engineering

# %%
#categorising annual income in low, middle and high income
def func(x):
    if (x<= 50_000):
        return 'Low Income'
    elif (x>50_000) and (x<=150_000):
        return 'Middle Income'
    elif (x>150_000):
        return 'High Income'

df['income_bracket'] = df['annual_income'].apply(func)

# %%
df['income_bracket'].value_counts().reset_index()
# Out:
#   income_bracket   count
# 0     Low Income  481743
# 1  Middle Income  360164
# 2    High Income    6656

# %%
#categorising credit score in to poor,fair,good and excellent credit score
def agg(x):
    if (x <=550):
        return 'Poor'
    elif (x > 550) and (x<680):
        return 'Fair'
    elif (x>=680) and (x<800):
        return 'Good'
    elif (x>=800):
        return 'Excellent'

df['credit_score_bracket'] = df['credit_score'].apply(agg)

# %%
df['credit_score_bracket'].value_counts().reset_index()
# Out:
#   credit_score_bracket   count
# 0                 Good  426194
# 1                 Fair  397975
# 2            Excellent   14125
# 3                 Poor   10269

# %%
# Borrower Annual Debt to be paid
df['annual_debt_payment'] = (df['debt_to_income_ratio'] * df['annual_income']).round(2)

# %%
#Borrower monthly debt to be paid
df['monthly_debt_payment'] = (df['annual_debt_payment']/12).round(2)

# %%
df['monthly_income'] = (df['annual_income']/12).round(2)

# %%
dtype_counts = df.dtypes.value_counts()
for dtype, count in dtype_counts.items():
    print(f"  {dtype}: {count}")
# Out:
#   object: 9
#   float64: 8
#   int64: 2

# %%
#Total debt burden calculation
df['total_debt_burden'] = (df['loan_amount'] * df['interest_rate'] / 100) / (df['annual_income'] + 1)

# %%
# Extracted grade and subgrade from grade_subgrade
df['subgrade'] = (df['grade_subgrade'].str[1:].astype(int))
df['grade'] = (df['grade_subgrade'].str[0])

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['id', 'annual_income', 'debt_to_income_ratio', 'credit_score',
#        'loan_amount', 'interest_rate', 'gender', 'marital_status',
#        'education_level', 'employment_status', 'loan_purpose',
#        'grade_subgrade', 'loan_paid_back', 'dataset', 'income_bracket',
#        'credit_score_bracket', 'annual_debt_payment', 'monthly_debt_payment',
#        'monthly_income', 'total_debt_burden', 'subgrade', 'grade'],
#       dtype='object')>

# %%
train_df = df.iloc[:len(train_df)]
train_df.drop(columns=['grade_subgrade','dataset'],inplace=True)
# Out:
# C:\Users\HELLO\AppData\Local\Temp\ipykernel_18844\84739495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(columns=['grade_subgrade','dataset'],inplace=True)

# %%
train_df
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 0            0       29367.99                 0.084           736
# 1            1       22108.02                 0.166           636
# 2            2       49566.20                 0.097           694
# 3            3       46858.25                 0.065           533
# 4            4       25496.70                 0.053           665
# ...        ...            ...                   ...           ...
# 593989  593989       23004.26                 0.152           703
# 593990  593990       35289.43                 0.105           559
# 593991  593991       47112.64                 0.072           675
# 593992  593992       76748.44                 0.067           740
# 593993  593993       48959.52                 0.096           752
#
#         loan_amount  interest_rate  gender marital_status education_level  \
# 0           2528.42          13.67  Female         Single     High School
# ...

# %%
test_fdf = df.iloc[len(train_df):]
test_fdf.drop(columns=['grade_subgrade','loan_paid_back','dataset'],inplace=True)
test_fdf
# Out:
# C:\Users\HELLO\AppData\Local\Temp\ipykernel_18844\1129055631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_fdf.drop(columns=['grade_subgrade','loan_paid_back','dataset'],inplace=True)
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 593994  593994       28781.05                 0.049           626
# 593995  593995       46626.39                 0.093           732
# 593996  593996       54954.89                 0.367           611
# 593997  593997       25644.63                 0.110           671
# 593998  593998       25169.64                 0.081           688
# ...        ...            ...                   ...           ...
# 848558  848558       92835.97                 0.068           744
# ...

# %%
feature_cols = train_df.drop(columns=[target_col, "id"]).columns.tolist()
categorical_features = [
    col for col in feature_cols 
    if train_df[col].dtype in ["object", "category"]
]
numeric_features = [
    col for col in feature_cols 
    if train_df[col].dtype not in ["object", "category", "bool"]
]

# %%
#categorical_features
feature_cols
# Out:
# ['annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'gender',
#  'marital_status',
#  'education_level',
#  'employment_status',
#  'loan_purpose',
#  'income_bracket',
#  'credit_score_bracket',
#  'annual_debt_payment',
#  'monthly_debt_payment',
#  'monthly_income',
#  'total_debt_burden',
#  'subgrade',
#  'grade']

# %%
numeric_features
# Out:
# ['annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'annual_debt_payment',
#  'monthly_debt_payment',
#  'monthly_income',
#  'total_debt_burden',
#  'subgrade']

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold,train_test_split
from category_encoders import TargetEncoder
from sklearn.pipeline import make_pipeline,Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import roc_auc_score,classification_report,f1_score,accuracy_score,confusion_matrix
import lightgbm as lgb
from lightgbm import LGBMClassifier, early_stopping, log_evaluation
import xgboost as xgb
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
x = train_df.drop(columns=['id',target_col])
y = train_df[target_col]

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
pos = (y_train==1).sum()
neg = len(y_train)-pos
scale = pos / neg
print(f'Pos:', pos)
print(f'Neg:', neg)
print(f'scale_Pos_Weight:', scale)
# Out:
# Pos: 379692
# Neg: 95503
# scale_Pos_Weight: 3.975707569395726

# %%
len(y_train)-pos
# Out:
# 95503

# %%
preprocess = ColumnTransformer([
    ('targetencoder',TargetEncoder(),categorical_features)
], remainder='passthrough')

# %%
preprocess
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('targetencoder', TargetEncoder(),
#                                  ['gender', 'marital_status', 'education_level',
#                                   'employment_status', 'loan_purpose',
#                                   'income_bracket', 'credit_score_bracket',
#                                   'grade'])])

# %% [markdown]
# ## Trying LGBMClassifier

# %%
model = make_pipeline(
    preprocess,
    LGBMClassifier(scale_pos_weoght=scale)
)
model.fit(X_train,y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: scale_pos_weoght
# [LightGBM] [Warning] Unknown parameter: scale_pos_weoght
# [LightGBM] [Info] Number of positive: 379692, number of negative: 95503
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100785 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2346
# [LightGBM] [Info] Number of data points in the train set: 475195, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.799024 -> initscore=1.380203
# [LightGBM] [Info] Start training from score 1.380203
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('targetencoder',
#                                                   TargetEncoder(),
#                                                   ['gender', 'marital_status',
# ...

# %%
best_params_lgb = {
    "n_estimators": 2400,
    "learning_rate": 0.04799514605781845,
    "max_depth": 4,
    "num_leaves": 35,
    "subsample": 0.9906130959928888,
    "colsample_bytree": 0.6077506330189334,
    "min_child_samples": 57,
    "reg_lambda": 4.5,
    "scale_pos_weight": scale,
    "random_state": 42,
    "n_jobs": -1,
    "early_stopping_rounds": 200
}

# %%
lgbm = LGBMClassifier(**best_params_lgb,class_weight='balanced', verbosity=-1, )
lgb_best = make_pipeline(
    preprocess,
    lgbm
)

x_test_transform = lgb_best.named_steps['columntransformer'].transform(X_test)
lgb_best.named_steps['lgbmclassifier'].fit(
    lgb_best.named_steps['columntransformer'].transform(X_train),
    y_train,
    eval_set=[(x_test_transform, y_test)],
    eval_metric="auc",
    callbacks=[
        early_stopping(stopping_rounds=200),
        log_evaluation(period=50)
    ]
)
# Out:
# Training until validation scores don't improve for 200 rounds
# [50]	valid_0's auc: 0.912318	valid_0's binary_logloss: 0.282585
# [100]	valid_0's auc: 0.915287	valid_0's binary_logloss: 0.257936
# [150]	valid_0's auc: 0.916412	valid_0's binary_logloss: 0.253318
# [200]	valid_0's auc: 0.917408	valid_0's binary_logloss: 0.251663
# [250]	valid_0's auc: 0.918148	valid_0's binary_logloss: 0.250561
# [300]	valid_0's auc: 0.91863	valid_0's binary_logloss: 0.249857
# [350]	valid_0's auc: 0.919156	valid_0's binary_logloss: 0.249116
# [400]	valid_0's auc: 0.91971	valid_0's binary_logloss: 0.24847
# [450]	valid_0's auc: 0.920237	valid_0's binary_logloss: 0.247858
# [500]	valid_0's auc: 0.920657	valid_0's binary_logloss: 0.247317
# [550]	valid_0's auc: 0.921112	valid_0's binary_logloss: 0.246738
# [600]	valid_0's auc: 0.921556	valid_0's binary_logloss: 0.246137
# [650]	valid_0's auc: 0.921871	valid_0's binary_logloss: 0.245731
# [700]	valid_0's auc: 0.922157	valid_0's binary_logloss: 0.245416
# ...

# %%
y_predlgb = lgb_best.predict(X_test)
y_pred_problg = lgb_best.predict_proba(X_test)[:,1]
t_pred = lgb_best.predict_proba(test_fdf)[:,1]

# %%
print(f'AUC:', roc_auc_score(y_test,y_pred_problg))
print(f'Accuracy Score:', accuracy_score(y_test,y_predlgb))
print(f1_score(y_test,y_predlgb))
print(classification_report(y_test,y_predlgb))
print(f'n***confusion matrix')
print(confusion_matrix(y_test,y_predlgb))
# Out:
# AUC: 0.9243290202735438
# Accuracy Score: 0.90675005681866
# 0.9436732867587988
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.62      0.73     23997
#          1.0       0.91      0.98      0.94     94802
#
#     accuracy                           0.91    118799
#    macro avg       0.90      0.80      0.84    118799
# weighted avg       0.91      0.91      0.90    118799
#
# n***confusion matrix
# [[14923  9074]
#  [ 2004 92798]]

# %%
y_pred_tdf = model.predict(test_fdf)
y_pred_tdf = model.predict_proba(test_fdf)[:, 1]

# %%
y_pred_tdf[:10]
# Out:
# array([0.93763075, 0.98585475, 0.46450649, 0.93289153, 0.956451  ,
#        0.97355637, 0.98538324, 0.96976316, 0.92967409, 0.00420031])

# %% [markdown]
# ### Trying XGBClassifier

# %%
xgb_params = {
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'tree_method': 'hist',
    'max_depth': 6,
    'learning_rate': 0.01,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'min_child_weight': 20,
    'reg_alpha': 0.05,
    'reg_lambda': 0.1,
    'random_state': 42,
    'n_estimators': 2200,
    'predictor': 'auto',
    'n_jobs': -1
}

# %%
model_xgb = make_pipeline(
    preprocess,
    XGBClassifier(**xgb_params)
)
model_xgb.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('targetencoder',
#                                                   TargetEncoder(),
#                                                   ['gender', 'marital_status',
#                                                    'education_level',
#                                                    'employment_status',
#                                                    'loan_purpose',
#                                                    'income_bracket',
#                                                    'credit_score_bracket',
#                                                    'grade'])])),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_byleve...
#                                feature_types=None, feature_weights=None,
# ...

# %%
y_pred_train_xg = model.predict_proba(X_train)
y_pred_xg = model.predict(X_test)
y_pred_test_xg = model.predict_proba(X_test)[:, 1]

# %%
print(f'AUC:', roc_auc_score(y_test,y_pred_test_xg))
print(f'Accuracy Score:', accuracy_score(y_test,y_pred_xg))
print(f1_score(y_test,y_pred_xg))
print(classification_report(y_test,y_pred_xg))
print(confusion_matrix(y_test,y_predlgb))
# Out:
# AUC: 0.9208041968341054
# Accuracy Score: 0.9050833761226946
# 0.9428635129109408
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.60      0.72     23997
#          1.0       0.91      0.98      0.94     94802
#
#     accuracy                           0.91    118799
#    macro avg       0.90      0.79      0.83    118799
# weighted avg       0.90      0.91      0.90    118799
#
# [[14923  9074]
#  [ 2004 92798]]

# %%
xgb_final_pred = model.predict_proba(test_fdf)[:, 1]

# %% [markdown]
# ### Trying CatBoost

# %%
catboost_params = {
    'iterations': 2000,
    'learning_rate': 0.03,
    'depth': 6,
    'l2_leaf_reg': 3,
    'eval_metric': 'AUC',
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.85,
    'auto_class_weights':'Balanced',
    'random_state': 42
}
print(f'CatBoost Training Configuration Successful')
# Out:
# CatBoost Training Configuration Successful

# %%
model_cat = make_pipeline(
    preprocess,
    CatBoostClassifier(**catboost_params, verbose=200)
)
model_cat.fit(X_train,y_train)
# Out:
# 0:	total: 460ms	remaining: 15m 20s
# 200:	total: 33.9s	remaining: 5m 3s
# 400:	total: 1m 6s	remaining: 4m 25s
# 600:	total: 1m 39s	remaining: 3m 52s
# 800:	total: 2m 13s	remaining: 3m 19s
# 1000:	total: 2m 47s	remaining: 2m 47s
# 1200:	total: 3m 20s	remaining: 2m 13s
# 1400:	total: 3m 54s	remaining: 1m 40s
# 1600:	total: 4m 27s	remaining: 1m 6s
# 1800:	total: 5m 1s	remaining: 33.3s
# 1999:	total: 5m 33s	remaining: 0us
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('targetencoder',
#                                                   TargetEncoder(),
#                                                   ['gender', 'marital_status',
#                                                    'education_level',
#                                                    'employment_status',
#                                                    'loan_purpose',
# ...

# %%
cat_pred = model_cat.predict(X_test)
cat_predt = model_cat.predict_proba(X_test)[:,1]

# %%
print(f'AUC:', roc_auc_score(y_test,cat_predt))
print(f'Accuracy Score:', accuracy_score(y_test,cat_pred))
print(f1_score(y_test,cat_pred))
print(classification_report(y_test,cat_pred))
print(confusion_matrix(y_test,cat_pred))
# Out:
# AUC: 0.9228098799193356
# Accuracy Score: 0.8710426855444912
# 0.9168764649709176
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.79      0.71     23997
#          1.0       0.94      0.89      0.92     94802
#
#     accuracy                           0.87    118799
#    macro avg       0.80      0.84      0.81    118799
# weighted avg       0.88      0.87      0.88    118799
#
# [[18987  5010]
#  [10310 84492]]

# %%
cat_tdf = model_cat.predict_proba(test_fdf)[:, 1]

# %%
proba = 0.45 * y_pred_problg + 0.35 * y_pred_test_xg + 0.20 * cat_predt

# %%
proba[:10]
# Out:
# array([0.78108117, 0.99864561, 0.33180158, 0.72096927, 0.99182108,
#        0.81521692, 0.99115563, 0.66360287, 0.81820151, 0.98006171])

# %% [markdown]
# ### PREDICTION

# %% [markdown]
# #### LGBMClassifier Prediction

# %%
predicted = pd.DataFrame({
    'id':test_fdf['id'].values,
    'loan_paid_back':t_pred
})

# %%
predicted.head(10)
# Out:
#        id  loan_paid_back
# 0  593994        0.933432
# 1  593995        0.978318
# 2  593996        0.521423
# 3  593997        0.907822
# 4  593998        0.966810
# 5  593999        0.970948
# 6  594000        0.986583
# 7  594001        0.975366
# 8  594002        0.957879
# 9  594003        0.002270

# %% [markdown]
# ### XGBoost Classifier

# %%
prediction2 = pd.DataFrame({
    'id':test_fdf['id'].values,
    'loan_paid_back':xgb_final_pred
})

prediction2.head(10)
# Out:
#        id  loan_paid_back
# 0  593994        0.937631
# 1  593995        0.985855
# 2  593996        0.464506
# 3  593997        0.932892
# 4  593998        0.956451
# 5  593999        0.973556
# 6  594000        0.985383
# 7  594001        0.969763
# 8  594002        0.929674
# 9  594003        0.004200

# %% [markdown]
# ### CatBoostClassifier Prediction

# %%
prediction3 = pd.DataFrame({
    'id':test_fdf['id'].values,
    'loan_paid_back':cat_tdf
})

prediction3.head(10)
# Out:
#        id  loan_paid_back
# 0  593994        0.773325
# 1  593995        0.920308
# 2  593996        0.151728
# 3  593997        0.773798
# 4  593998        0.873844
# 5  593999        0.897522
# 6  594000        0.946613
# 7  594001        0.880871
# 8  594002        0.792327
# 9  594003        0.000539

# %%
import shutil
predicted.to_csv('submission6_loan.csv',index=False)
shutil.make_archive('predicted6', 'zip', '.', 'submission6_loan.csv')
# Out:
# 'C:\\Users\\HELLO\\predicted6.zip'
